# %% [markdown]
# <a href="https://colab.research.google.com/github/T3widianto22/T3widianto22/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
filennya = files.upload()
# Out:
#      <input type="file" id="files-af6656ee-112a-4d7b-92a4-4fa24ceccede" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-af6656ee-112a-4d7b-92a4-4fa24ceccede">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filennya
# Out:
# {'AnyConv.com__REKAP TAGIHAN TJW 2022 NEW  (7).csv': b',PT TRITAMA JAYA WISATA,,,,,,,,,,,,,,,,,,\n,REKAP TAGIHAN PER JANUARI 2022,,,,,,,,,,,,,,,,,,\n,,,,,,,,,,,,,,,,,,,\nCustomer Code,NO INVOICE,Customer Name,Attention To,Date,Due Date, SELL, Outstanding, BASIC PRICE, CN, PAJAK 1%, PROFIT,Passenger,FLIGHT,Ticket,VENDOR,BANK,Tgl Pembayaran, Jumlah ,\n,HOTJW-31025,KEMENTERIAN PERINDUSTRIAN,BOWO MR,12-Jan-22,27-Jan-22," 1,211,100.00 ",," 920,300.00 "," 50,000.00 "," 12,111.00 "," 228,689.00 ",TUNGGONO AGUS MR,LION AIR,CGK SUB ID 12JAN22,ANNISA TRAVEL,MANDIRI,26-Feb-22," 11,214,800.00 ",\n,HOTJW-31025,KEMENTERIAN PERINDUSTRIAN,BOWO MR,12-Jan-22,27-Jan-22," 1,211,100.00 ",," 920,300.00 "," 50,000.00 "," 12,111.00 "," 228,689.00 ",SUHANTA MR,LION AIR,CGK SUB ID 12JAN22,ANNISA TRAVEL,,,,\n,HOTJW-31025,KEMENTERIAN PERINDUSTRIAN,BOWO MR,12-Jan-22,27-Jan-22," 1,211,100.00 ",," 920,300.00 "," 50,000.00 "," 12,111.00 "," 228,689.00 ",SUSETYO BOWO MR,LION AIR,CGK SUB ID 12JAN22,ANNISA TRAVEL,,,,\
# ...

# %%
import io
df = pd.read_csv(io.StringIO(filennya['AnyConv.com__REKAP TAGIHAN TJW 2022 NEW  (7).csv'].decode('utf-8')))
print(df)
# Out:
#         Unnamed: 0          PT TRITAMA JAYA WISATA                 Unnamed: 2  \
# 0              NaN  REKAP TAGIHAN PER JANUARI 2022                        NaN
# 1              NaN                             NaN                        NaN
# 2    Customer Code                      NO INVOICE              Customer Name
# 3              NaN                     HOTJW-31025  KEMENTERIAN PERINDUSTRIAN
# 4              NaN                     HOTJW-31025  KEMENTERIAN PERINDUSTRIAN
# ..             ...                             ...                        ...
# 110            NaN                             NaN                        NaN
# 111            NaN                             NaN   OUTSTANDING JANUARI 2022
# 112            NaN                             NaN                  PEMASUKAN
# 113            NaN                             NaN                 ENTERTAIN
# 114            NaN                             NaN           JUMLAH PEMASUKAN
#
# ...

# %%
df.head()
# Out:
#       Unnamed: 0          PT TRITAMA JAYA WISATA                 Unnamed: 2  \
# 0            NaN  REKAP TAGIHAN PER JANUARI 2022                        NaN
# 1            NaN                             NaN                        NaN
# 2  Customer Code                      NO INVOICE              Customer Name
# 3            NaN                     HOTJW-31025  KEMENTERIAN PERINDUSTRIAN
# 4            NaN                     HOTJW-31025  KEMENTERIAN PERINDUSTRIAN
#
#      Unnamed: 3 Unnamed: 4 Unnamed: 5      Unnamed: 6    Unnamed: 7  \
# 0           NaN        NaN        NaN             NaN           NaN
# 1           NaN        NaN        NaN             NaN           NaN
# 2  Attention To       Date   Due Date            SELL   Outstanding
# 3       BOWO MR  12-Jan-22  27-Jan-22   1,211,100.00            NaN
# 4       BOWO MR  12-Jan-22  27-Jan-22   1,211,100.00            NaN
#
#      Unnamed: 8   Unnamed: 9  Unnamed: 10   Unnamed: 11       Unnamed: 12  \
# ...
